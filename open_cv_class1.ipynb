# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/opencv-learn/blob/main/open_cv_class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image

# %matplotlib inline

# %%
import requests

def download_image(url, save_path):
    try:
        # Fazendo o download da imagem
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Verifica se houve algum erro

        # Salvando a imagem em um arquivo
        with open(save_path, 'wb') as file:
            for chunk in response.iter_content(1024):
                file.write(chunk)

        print(f"Imagem baixada e salva em: {save_path}")
    except requests.exceptions.RequestException as e:
        print(f"Erro ao baixar a imagem: {e}")

# URL da imagem que você deseja baixar - MODIFIED TO A VALID IMAGE URL
url = "https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Cat03.jpg/1200px-Cat03.jpg"
# Caminho onde a imagem será salva
save_path = "minha_imagem.jpg"

download_image(url, save_path)
# Out:
# Imagem baixada e salva em: minha_imagem.jpg

# %%
imagem= cv2.imread("/content/minha_imagem.jpg",1)

# %%
print(imagem)
Image(imagem)
plt.imshow(imagem)
# Out:
# [[[176 209 218]
#   [175 208 217]
#   [176 207 216]
#   ...
#   [208 220 230]
#   [208 220 230]
#   [208 220 230]]
#
#  [[176 209 218]
#   [175 208 217]
#   [176 207 216]
#   ...
#   [209 221 231]
#   [209 221 231]
#   [209 221 231]]
#
#  [[176 209 218]
#   [174 207 216]
#   [174 207 216]
#   ...
#   [210 222 232]
#   [210 222 232]
#   [210 222 232]]
#
#  ...
#
#  [[118 152 182]
#   [118 152 182]
#   [120 154 184]
#   ...
#   [198 214 226]
#   [198 214 226]
#   [197 213 225]]
#
#  [[117 151 181]
#   [118 152 182]
#   [119 153 183]
#   ...
#   [199 215 227]
#   [198 214 226]
#   [197 213 225]]
#
#  [[117 151 181]
#   [118 152 182]
#   [119 153 183]
#   ...
#   [198 214 226]
#   [198 214 226]
#   [197 213 225]]]

# %%
img_reversed = imagem[:,:,::-1]
print(imagem)
Image(imagem)
plt.imshow(imagem)
# Out:
# [[[176 209 218]
#   [175 208 217]
#   [176 207 216]
#   ...
#   [208 220 230]
#   [208 220 230]
#   [208 220 230]]
#
#  [[176 209 218]
#   [175 208 217]
#   [176 207 216]
#   ...
#   [209 221 231]
#   [209 221 231]
#   [209 221 231]]
#
#  [[176 209 218]
#   [174 207 216]
#   [174 207 216]
#   ...
#   [210 222 232]
#   [210 222 232]
#   [210 222 232]]
#
#  ...
#
#  [[118 152 182]
#   [118 152 182]
#   [120 154 184]
#   ...
#   [198 214 226]
#   [198 214 226]
#   [197 213 225]]
#
#  [[117 151 181]
#   [118 152 182]
#   [119 153 183]
#   ...
#   [199 215 227]
#   [198 214 226]
#   [197 213 225]]
#
#  [[117 151 181]
#   [118 152 182]
#   [119 153 183]
#   ...
#   [198 214 226]
#   [198 214 226]
#   [197 213 225]]]

# %%
b, r, g= cv2.split(imagem)
# Show the channels
plt.figure(figsize=[20, 5])

plt.subplot(141);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

# Merge the individual channels into a BGR image
imgMerged = cv2.merge((b, g, r))
# Show the merged output
plt.subplot(144)
plt.imshow(imgMerged[:, :, ::-1])
plt.title("Merged Output")
# Out:
# Text(0.5, 1.0, 'Merged Output')

# %%
imagem.shape
# Out:
# (1199, 1200, 3)

# %%
# Convertendo a imagem para escala de cinza
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

print(imagem_cinza)
Image(imagem)
plt.imshow(imagem_cinza, cmap='gray') # Exibir em escala de cinza
imagem.shape
# Out:
# [[208 207 206 ... 222 222 222]
#  [208 207 206 ... 223 223 223]
#  [208 206 206 ... 224 224 224]
#  ...
#  [157 157 159 ... 216 216 215]
#  [156 157 158 ... 217 216 215]
#  [156 157 158 ... 216 216 215]]
# (1199, 1200, 3)

# %%
# Split the image into the B,G,R components
img_NZ_bgr = cv2.imread("/content/minha_imagem.jpg", 1)
b, g, r = cv2.split(img_NZ_bgr)

# Show the channels
plt.figure(figsize=[20, 5])

plt.subplot(141);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

# Merge the individual channels into a BGR image
imgMerged = cv2.merge((b, g, r))
# Show the merged output
plt.subplot(144)
plt.imshow(imgMerged[:, :, ::-1])
plt.title("Merged Output")
# Out:
# Text(0.5, 1.0, 'Merged Output')
